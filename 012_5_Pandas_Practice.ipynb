# %% [markdown]
# <a href="https://colab.research.google.com/github/Ovizero01/Python-Machine-Learning/blob/main/012_5_Pandas_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **Create a Pandas Series from the list [10, 20, 30, 40, 50]. Print the Series, its index, and data type. Then create a DataFrame with columns "Name", "Age", and "City" containing at least 4 rows of data.**

# %%
lst = [10, 20, 30, 40, 50]
df = pd.DataFrame(lst, columns = ['Numbers'])
num = df['Numbers']
print("Series: ")
print(num)
print(f"Index: {num.index}")
print(f"Datatype: {num.dtype}")
# Out:
# Series:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# Name: Numbers, dtype: int64
# Index: RangeIndex(start=0, stop=5, step=1)
# Datatype: int64

# %% [markdown]
# **Create a DataFrame with columns "Name", "Age", and "City" containing at least 4 rows of data.**

# %%
my_dict = {
    'Name': ['Alice', 'Bob', 'Charlie', 'Ovi'],
    'Age': [25,29,28,24],
    'City': ['New York', 'Chicago', 'Miami', 'Dhaka']
}
dict_df = pd.DataFrame(my_dict)
dict_df
# Out:
#       Name  Age      City
# 0    Alice   25  New York
# 1      Bob   29   Chicago
# 2  Charlie   28     Miami
# 3      Ovi   24     Dhaka

# %% [markdown]
# **Using any DataFrame, write code to print the number of rows and columns, column data types (.dtypes), and summary statistics (.describe())**.

# %%
df = pd.read_csv('student_data.csv')
print(f"Number of rows and columns: {df.shape}")
print(f"\nColumn data types: \n{df.dtypes}")
print("\nStatistical Info: ")
df.describe()
# Out:
# Number of rows and columns: (20, 9)
#
# Column data types:
# StudentID                object
# FullName                 object
# Data Structure Marks    float64
# Algorithm Marks         float64
# Python Marks            float64
# CompletionStatus         object
# EnrollmentDate           object
# Instructor               object
# Location                 object
# dtype: object
#
# Statistical Info:
#        Data Structure Marks  Algorithm Marks  Python Marks
# count             16.000000        16.000000     15.000000
# mean              84.000000        84.000000     85.666667
# std                6.501282         6.501282      5.394000
# min               72.000000        72.000000     76.000000
# 25%               79.500000        79.500000     83.000000
# 50%               85.500000        85.500000     85.000000
# 75%               88.250000        88.250000     88.500000
# max               94.000000        94.000000     95.000000

# %% [markdown]
# Create a DataFrame using the dictionary below:
# data = {
#     'Product': ['Pen', 'Book', 'Eraser', 'Pencil'],
#     'Price': [10, 50, 5, 7],
#     'Quantity': [100, 60, 200, 150]
# }

# %%
data = {
    'Product': ['Pen', 'Book', 'Eraser', 'Pencil'],
    'Price': [10, 50, 5, 7],
    'Quantity': [100, 60, 200, 150]
}
df = pd.DataFrame(data)
df
print(f"Columns: {df.columns}")
print(f"Index: {df.index}")
print("Accessing one full row: ")
df.loc[2]
# Out:
# Columns: Index(['Product', 'Price', 'Quantity'], dtype='object')
# Index: RangeIndex(start=0, stop=4, step=1)
# Accessing one full row:
# Product     Eraser
# Price            5
# Quantity       200
# Name: 2, dtype: object

# %% [markdown]
# **Using .loc[] and .iloc[], show the first row, the second column, and a 2×2 block    from the middle of your DataFrame.**

# %%
print(f"First row using loc: \n{df.loc[0]}\n")
print(f"Second column using loc: \n{df.loc[:, 'FullName']}\n")
print(f"First row using iloc: \n{df.iloc[0]}\n")
print(f"Second column using iloc: \n{df.iloc[:, 1]}\n")
print("2×2 block from the middle using .loc[]:")
print(df.loc[9:10, ['Algorithm Marks', 'Python Marks']])
print("\n2×2 block from the middle using .iloc[]:")
print(df.iloc[9:11,3:5])
# Out:
# First row using loc:
# StudentID                    PH1001
# FullName                Alif Rahman
# Data Structure Marks           85.0
# Algorithm Marks                85.0
# Python Marks                   88.0
# CompletionStatus          Completed
# EnrollmentDate           2024-01-15
# Instructor                Mr. Karim
# Location                      Dhaka
# Name: 0, dtype: object
#
# Second column using loc:
# 0          Alif Rahman
# 1        Fatima Akhter
# 2        Imran Hossain
# 3     Jannatul Ferdous
# 4          Kamal Uddin
# 5          Laila Begum
# 6       Mahmudul Hasan
# 7          Nadia Islam
# 8           Omar Faruq
# 9         Priya Sharma
# 10        Rahim Sheikh
# 11     Sadia Chowdhury
# 12        Tanvir Ahmed
# 13          Urmi Akter
# 14        Wahiduzzaman
# 15        Ziaur Rahman
# 16         Afsana Mimi
# 17         Babul Ahmed
# 18        Faria Rahman
# 19          Nasir Khan
# Name: FullName, dtype: object
#
# First row using iloc:
# StudentID                    PH1001
# FullName                Alif Rahman
# Data Structure Marks           85.0
# Algorithm Marks                85.0
# Python Marks                   88.0
# CompletionStatus          Completed
# EnrollmentDate           2024-01-15
# Instructor                Mr. Karim
# Location                      Dhaka
# Name: 0, dtype: object
#
# Second column using iloc:
# 0          Alif Rahman
# 1        Fatima Akhter
# 2        Imran Hossain
# 3     Jannatul Ferdous
# 4          Kamal Uddin
# 5          Laila Begum
# 6       Mahmudul Hasan
# 7          Nadia Islam
# 8           Omar Faruq
# 9         Priya Sharma
# 10        Rahim Sheikh
# 11     Sadia Chowdhury
# 12        Tanvir Ahmed
# 13          Urmi Akter
# 14        Wahiduzzaman
# 15        Ziaur Rahman
# 16         Afsana Mimi
# 17         Babul Ahmed
# 18        Faria Rahman
# 19          Nasir Khan
# Name: FullName, dtype: object
#
# 2×2 block from the middle using .loc[]:
#     Algorithm Marks  Python Marks
# 9              89.0          88.0
# 10              NaN          91.0
#
# 2×2 block from the middle using .iloc[]:
#     Algorithm Marks  Python Marks
# 9              89.0          88.0
# 10              NaN          91.0

# %% [markdown]
#  Create a 4×3 DataFrame of student names and marks. Drop one column using .drop(), drop one row by index

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'Diana'],
    'Math': [85, 90, 78, 88],
    'English': [92, 81, 85, 89]
}
df = pd.DataFrame(data)
# dropping column
df.drop('English', axis = 1, inplace = True)
# dropping row
df.drop(2, inplace = True)
df
# Out:
#     Name  Math
# 0  Alice    85
# 1    Bob    90
# 3  Diana    88

# %% [markdown]
# **Create a DataFrame of employees with columns "Name", "Department", and "Salary". Sort it by "Salary" in ascending order and by "Name" in descending order.**

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'Diana'],
    'Department': ['HR', 'IT', 'Finance', 'Marketing'],
    'Salary': [40000, 55000, 60000, 52000]
}
df = pd.DataFrame(data)
copy1 = df.sort_values(['Salary', 'Name'], ascending = [1, 0])
copy1
# Out:
#       Name Department  Salary
# 0    Alice         HR   40000
# 3    Diana  Marketing   52000
# 1      Bob         IT   55000
# 2  Charlie    Finance   60000

# %% [markdown]
# **Create a DataFrame of 8 students with columns "Name" and "Score". Filter and print students with Score > 60 and those with Score < 40.**

# %%
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'Diana', 'Ethan', 'Fiona', 'George', 'Hannah'],
    'Score': [85, 92, 78, 88, 95, 80, 70, 90]
}
df = pd.DataFrame(data)
high_scores = df.loc[(df['Score'] > 60)]
print(f"High Scores: \n{high_scores}\n")
low_scores = df.loc[(df['Score'] < 40)]
print(f"Low Scores: \n{low_scores}")
# Out:
# High Scores:
#       Name  Score
# 0    Alice     85
# 1      Bob     92
# 2  Charlie     78
# 3    Diana     88
# 4    Ethan     95
# 5    Fiona     80
# 6   George     70
# 7   Hannah     90
#
# Low Scores:
# Empty DataFrame
# Columns: [Name, Score]
# Index: []
